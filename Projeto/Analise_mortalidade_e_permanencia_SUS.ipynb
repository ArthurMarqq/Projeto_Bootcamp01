# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurMarqq/Projeto_Bootcamp01/blob/main/Projeto/Analise_mortalidade_e_permanencia_SUS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Projeto 01 Bootcamp Alura

# %% [markdown]
# **Considerações iniciais**:
#
# Esse projeto usará dados referentes as taxas de mortalidade no SUS de Janeiro de 2008 até Setembro de 2021.
#
# A idéia inicial é tentar, utilizando os aprendizados do primeiro módulo, traçar hipóteses a fim de entender melhor o comportamento dos dados.
#
#
# **Outras considerações importantes para facilitar a leitura**:
#
# A taxa de mortalidade é a razão entre a quantidade de óbitos e o número de AIH aprovadas, computadas como internações, no período, multiplicada por 100. (**informação retirada das notas técnicas da base de dados do datasus**)
#
# Os links estarão devidamente anexados no final desse projeto.

# %%
# importando o pandas
import pandas as pd

# %%
# guardando os arquivos CSV dentro de variaveis diferentes

dados_taxa_mortalidade = pd.read_csv('/content/A123627189_28_143_208.csv', encoding = "ISO-8859-1", 
                                     sep=";", skiprows=3, skipfooter=12, thousands=".", decimal=",")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.

# %% [markdown]
# Agora precisamos olhar se existe algum valor NaN no dataset

# %%
dados_taxa_mortalidade.isnull().sum().sum()
# Out:
# 2

# %% [markdown]
# Existem dois valores vazios no dataset, ou seja, precisamos de alguma forma lidar com isso, uma vez que esses valores podem modificar os resultados das análises de uma forma negativa.

# %%
dados_taxa_mortalidade.describe()
# Out:
#         2008/Jan   2008/Fev   2008/Mar  ...   2021/Ago   2021/Set      Total
# count  27.000000  27.000000  27.000000  ...  27.000000  26.000000  27.000000
# mean    4.855556   5.244444   5.174074  ...   5.459259   5.446154   5.270370
# std     1.211589   1.310999   1.263570  ...   0.617849   0.717346   0.874781
# min     3.000000   3.600000   2.800000  ...   4.300000   3.800000   3.900000
# 25%     4.100000   4.550000   4.450000  ...   5.050000   5.050000   4.750000
# 50%     4.700000   4.800000   4.900000  ...   5.400000   5.500000   5.100000
# 75%     5.200000   5.600000   5.700000  ...   5.800000   5.875000   5.450000
# max     8.600000  10.200000   9.600000  ...   6.900000   6.900000   8.500000
#
# [8 rows x 166 columns]

# %%
dados_taxa_mortalidade.head()
# Out:
#   Unidade da Federação  2008/Jan  2008/Fev  ...  2021/Ago  2021/Set  Total
# 0          11 Rondônia       3.0       3.6  ...       4.7       5.6    4.4
# 1              12 Acre       3.5       4.5  ...       4.8       NaN    4.8
# 2          13 Amazonas       4.6       4.7  ...       5.0       5.3    5.1
# 3           14 Roraima       4.5       4.6  ...       6.9       6.6    5.3
# 4              15 Pará       3.4       3.6  ...       4.3       3.8    3.9
#
# [5 rows x 167 columns]

# %%
colunas_taxa_mortalidade = dados_taxa_mortalidade.mean().index.tolist()
colunas_taxa_mortalidade.insert(0, "Unidade da Federação")

# %%
usaveis_taxa_mortalidade = dados_taxa_mortalidade[colunas_taxa_mortalidade]

# %%
usaveis_taxa_mortalidade = dados_taxa_mortalidade.set_index("Unidade da Federação")

# %%
usaveis_taxa_mortalidade.tail()
# Out:
#                        2008/Jan  2008/Fev  2008/Mar  ...  2021/Ago  2021/Set  Total
# Unidade da Federação                                 ...
# 43 Rio Grande do Sul        5.5       6.0       5.7  ...       6.3       6.2    6.1
# 50 Mato Grosso do Sul       4.1       4.6       4.5  ...       5.4       5.2    4.8
# 51 Mato Grosso              3.4       4.2       4.2  ...       4.8       5.0    4.5
# 52 Goiás                    4.9       4.7       4.9  ...       5.6       5.8    5.0
# 53 Distrito Federal         6.4       6.7       6.0  ...       5.3       5.5    6.3
#
# [5 rows x 166 columns]
