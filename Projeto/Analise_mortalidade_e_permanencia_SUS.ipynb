# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurMarqq/Projeto_Bootcamp01/blob/main/Projeto/Analise_mortalidade_e_permanencia_SUS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Projeto 01 Bootcamp Alura

# %% [markdown]
# **Considerações iniciais**:
#
# Esse projeto usará dois arquivos de data, um contendo dados referentes as taxas de mortalidade no SUS de Janeiro de 2008 até Setembro de 2021, o outro com dados referentes a média de permanência dentro dessas unidades, novamente entre Janeiro de 2008 até Setembro de 2021
#
# A idéia inicial é tentar, utilizando os aprendizados do primeiro módulo, traçar se existe alguma relação entre esses dados.
#
#
# **Outras considerações importantes para facilitar a leitura**:
#
# A média de permanência é em relação as internações referentes às AIH aprovadas, computadas como interanções no período (**informação retirada das notas técnicas da base de dados do datatus**)
#
# A taxa de mortalidade é a razão entre a quantidade de óbitos e o número de AIH aprovadas, computadas como internações, no período, multiplicada por 100. (**informação retirada das notas técnicas da base de dados do datasus**)
#
# Os links estarão devidamente anexados no final desse projeto.

# %%
#importando o pandas para conseguir olhar os dados
import pandas as pd

# %%
# guardando os arquivos dentro de variaveis diferentes para facilitar as análises

dados_taxa_mortalidade = pd.read_csv('/content/A123627189_28_143_208.csv', encoding = "ISO-8859-1", 
                                     sep=";", skiprows=3, skipfooter=12, thousands=".", decimal=",")

dados_media_permanencia = pd.read_csv('/content/A124453189_28_143_208.csv', encoding = "ISO-8859-1", 
                                      sep=";", skiprows=3, skipfooter=12, thousands=".", decimal=",")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   import sys

# %% [markdown]
# Após importar ambos os datasets, precisamos dar uma olhada em como os dados estão distribuidos, se estão faltando informações, quantas linhas e colunas estamos lidando e como está a organização no geral.

# %%
dados_taxa_mortalidade.head()
# Out:
#   Unidade da Federação  2008/Jan  2008/Fev  ...  2021/Ago  2021/Set  Total
# 0          11 Rondônia       3.0       3.6  ...       4.7       5.6    4.4
# 1              12 Acre       3.5       4.5  ...       4.8       NaN    4.8
# 2          13 Amazonas       4.6       4.7  ...       5.0       5.3    5.1
# 3           14 Roraima       4.5       4.6  ...       6.9       6.6    5.3
# 4              15 Pará       3.4       3.6  ...       4.3       3.8    3.9
#
# [5 rows x 167 columns]

# %%
dados_media_permanencia.head()
# Out:
#   Unidade da Federação  2008/Jan  2008/Fev  ...  2021/Ago  2021/Set  Total
# 0          11 Rondônia      1.38      1.36  ...      4.03      4.34   2.79
# 1              12 Acre      1.44      3.06  ...      4.15       NaN   3.01
# 2          13 Amazonas      1.60      1.91  ...      3.65      3.71   2.98
# 3           14 Roraima      1.56      1.16  ...      4.84      4.43   2.78
# 4              15 Pará      1.41      1.40  ...      3.37      3.04   2.23
#
# [5 rows x 167 columns]

# %%
colunas_media_permanencia = dados_media_permanencia.mean().index.tolist()
colunas_media_permanencia.insert(0, "Unidade da Federação")

# %%
colunas_taxa_mortalidade = dados_taxa_mortalidade.mean().index.tolist()
colunas_taxa_mortalidade.insert(0, "Unidade da Federação")

# %%
dados_media_permanencia[colunas_media_permanencia].head()
# Out:
#   Unidade da Federação  2008/Jan  2008/Fev  ...  2021/Ago  2021/Set  Total
# 0          11 Rondônia      1.38      1.36  ...      4.03      4.34   2.79
# 1              12 Acre      1.44      3.06  ...      4.15       NaN   3.01
# 2          13 Amazonas      1.60      1.91  ...      3.65      3.71   2.98
# 3           14 Roraima      1.56      1.16  ...      4.84      4.43   2.78
# 4              15 Pará      1.41      1.40  ...      3.37      3.04   2.23
#
# [5 rows x 167 columns]
